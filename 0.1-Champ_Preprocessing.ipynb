# %% [markdown]
# # Data Preprocessing #

# %% [markdown]
# ### Imports ###

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ### Data Preview ###

# %%
data = pd.read_csv('Animal_IO_Data_0.csv') # https://data.louisvilleky.gov/sites/default/files/Animal_IO_Data_0.csv
print("Total Observations: ", len(data))
data.head(10)
# Out:
# Total Observations:  150842
#   AnimalID AnimalType           IntakeDate  IntakeType IntakeSubtype  \
# 0  A366370        CAT  2008-11-07 10:50:00       STRAY           OTC
# 1  A366531        CAT  2008-11-10 10:20:00       STRAY           OTC
# 2  A532367       BIRD  2014-07-23 23:21:00  CONFISCATE       CRUELTY
# 3  A532474      OTHER  2014-07-24 18:29:00  ET REQUEST           NaN
# 4  A281756        DOG  2006-09-11 18:10:00   OWNER SUR           OTC
# 5  A451184       BIRD  2012-01-29 15:25:00   OWNER SUR         FIELD
# 6  A256128        DOG  2005-11-26 12:35:00       STRAY         FIELD
# 7  A314432        CAT  2007-06-15 17:13:00   OWNER SUR           OTC
# 8  A316619        DOG  2007-06-29 20:10:00       STRAY         FIELD
# 9  A317335        CAT  2007-07-05 21:30:00       STRAY           OTC
#
#   PrimaryColor               PrimaryBreed      SecondaryBreed         Gender  \
# 0        WHITE         DOMESTIC SHORTHAIR                 NaN  NEUTERED MALE
# 1        BLACK         DOMESTIC SHORTHAIR  DOMESTIC SHORTHAIR        UNKNOWN
# 2          RED                    CHICKEN                 NaN           MALE
# 3        BROWN                        BAT                 NaN        UNKNOWN
# 4        WHITE           PIT BULL TERRIER                 NaN           MALE
# 5        BLACK                    CHICKEN                 NaN        UNKNOWN
# 6        BROWN  AMERICAN PIT BULL TERRIER                 MIX           MALE
# 7  BROWN TABBY         DOMESTIC SHORTHAIR                 NaN        UNKNOWN
# 8        WHITE         LABRADOR RETRIEVER                 MIX           MALE
# 9         GRAY         DOMESTIC SHORTHAIR                 NaN        UNKNOWN
#
#   SecondaryColor  ... IntakeInternalStatus IntakeAsilomarStatus  \
# 0          BROWN  ...              FEARFUL              HEALTHY
# 1            NaN  ...               NORMAL              HEALTHY
# 2          BLACK  ...                OTHER              HEALTHY
# 3            NaN  ...                OTHER              HEALTHY
# 4          BROWN  ...               NORMAL              HEALTHY
# 5          WHITE  ...               NORMAL              HEALTHY
# 6          WHITE  ...               NORMAL              HEALTHY
# 7            NaN  ...               NORMAL              HEALTHY
# 8            TAN  ...              FEARFUL              HEALTHY
# 9            NaN  ...               NORMAL              HEALTHY
#
#   ReproductiveStatusAtIntake          OutcomeDate OutcomeType OutcomeSubtype  \
# 0                    ALTERED  2008-11-12 15:46:00        EUTH          FERAL
# 1                    UNKNOWN  2008-11-19 20:10:00        EUTH     CONTAG DIS
# 2                    FERTILE  2014-11-05 15:49:00    TRANSFER            NaN
# 3                    UNKNOWN  2014-07-24 23:59:00        EUTH        MEDICAL
# 4                    FERTILE  2006-09-12 13:44:00        EUTH     TIME/SPACE
# 5                    UNKNOWN  2012-02-22 23:59:00    TRANSFER     RESCUE GRP
# 6                    FERTILE  2005-12-08 23:59:00        EUTH        MEDICAL
# 7                    UNKNOWN  2007-06-15 18:07:00        EUTH     TIME/SPACE
# 8                    FERTILE  2007-07-04 13:12:00        EUTH     TIME/SPACE
# 9                    UNKNOWN  2007-07-11 09:19:00        EUTH     TIME/SPACE
#
#   OutcomeReason OutcomeInternalStatus  OutcomeAsilomarStatus  \
# 0           NaN                   NaN  UNHEALTHY/UNTREATABLE
# 1           NaN                  SICK                HEALTHY
# 2           NaN                   NaN                HEALTHY
# 3           NaN                 OTHER                HEALTHY
# 4           NaN                   NaN                HEALTHY
# 5           NaN                NORMAL                HEALTHY
# 6           NaN                   NaN                HEALTHY
# 7           NaN                   NaN                HEALTHY
# 8           NaN                   NaN                HEALTHY
# 9           NaN                   NaN                HEALTHY
#
#   ReproductiveStatusAtOutcome
# 0                     ALTERED
# 1                     UNKNOWN
# 2                     FERTILE
# 3                     UNKNOWN
# 4                     FERTILE
# 5                     UNKNOWN
# 6                     FERTILE
# 7                     UNKNOWN
# 8                     FERTILE
# 9                     UNKNOWN
#
# [10 rows x 22 columns]

# %%
print(data.columns, '\n')
# Out:
# Index(['AnimalID', 'AnimalType', 'IntakeDate', 'IntakeType', 'IntakeSubtype',
#        'PrimaryColor', 'PrimaryBreed', 'SecondaryBreed', 'Gender',
#        'SecondaryColor', 'DOB', 'IntakeReason', 'IntakeInternalStatus',
#        'IntakeAsilomarStatus', 'ReproductiveStatusAtIntake', 'OutcomeDate',
#        'OutcomeType', 'OutcomeSubtype', 'OutcomeReason',
#        'OutcomeInternalStatus', 'OutcomeAsilomarStatus',
#        'ReproductiveStatusAtOutcome'],
#       dtype='object')

# %% [markdown]
# ### Scope ###
# The scope of the project was limited to only cats and dogs

# %%
data = data[(data['AnimalType'] == 'CAT') | (data['AnimalType'] == 'DOG')]
print("Total Observations: ", len(data))
# Out:
# Total Observations:  145886

# %% [markdown]
# ### Dropping Unhelpful Rows and Columns ###

# %% [markdown]
# #### For the purposes of this project, OutsideAsilomarStatus is redundant (OutcomeType) and ReproductiveStatusAtOutcome is irrelevant. ####

# %%
data = data.drop(['OutcomeAsilomarStatus', 'ReproductiveStatusAtOutcome'], axis = 1)

# %% [markdown]
# #### IntakeAsilomarStatus is redundant because the same IntakeInternalStatus always has the same IntakeAsilomarStatus. ####

# %%
data = data.drop(['IntakeAsilomarStatus'], axis = 1)

# %% [markdown]
# #### Rows without an OutcomeType will not be helpful in training our model. ####

# %%
data = data[pd.notnull(data['OutcomeType'])]
data = data.reset_index(drop = True)

# %% [markdown]
# #### Certain IntakeTypes will prevent any possible intervention in the outcome and certain outcomes cannot be avoided. ####
# For example, if an animal is brought in through a euthanasia request, nothing can be done to change the outcome. There are several instances of this and so they will not be included.

# %%
NPI_IntakeTypes = ['DISPOSAL', # disposal of dead animal
                   'ET REQUEST',  # euthanasia request
                   'EUTH REQ', # euthanasia request
                   'OUTSURGERY', # surgery
                   'QUARANTINE']  # isolated due to health/aggression reasons (almost always euthanized with fair reason)

NPI_IntakeSubtypes = ['BITE', # almost always euthanized for aggression
                      'EUTH REQ',  # euthanasia request
                      'DANGER DOG',  # dangerous dog (almost always euthanized with fair reason)
                      'POST SURG', # surgery
                      'RESCUE GRP', # always transferred
                      'POTDANGER']  # potential danger (almost always euthanized with fair reason)

NPI_OutcomeTypes = ['RTO',  # returned to owner (lost and found)
                    'DISPOSAL',  # disposing of dead animal
                    'TNR', # trap and release (animals taken and released after spayed/neutered)
                    'SNR', # similar to TNR
                    'RTF', # similar to TNR
                    'MISSING',  # uncontrollable/unknown outcome
                    'MISSING EX',  # uncontrollable/unknown outcome
                    'LOST EXP',  # uncontrollable/unknown outcome
                    'NO SHOW',  # uncontrollable/unknown outcome
                    'RELEASE',  # likely similar to TNR
                    'RELEASED']  # likely similar to TNR

NPI_ITs = data[data['IntakeType'].isin(NPI_IntakeTypes)].index
data = data.drop(NPI_ITs)

NPI_ISs = data[data['IntakeSubtype'].isin(NPI_IntakeSubtypes)].index
data = data.drop(NPI_ISs)

NPI_OTs = data[data['OutcomeType'].isin(NPI_OutcomeTypes)].index
data = data.drop(NPI_OTs)

data = data[data['IntakeInternalStatus'] != 'DEAD']  # animals that were dead on arrival
data = data[data['OutcomeSubtype'] != 'REQUESTED'] # euthanasia requested (improperly documented in IntakeType)

data = data.reset_index(drop=True)

# %% [markdown]
# ### Dropping Columns with Many Missing Values ###

# %% [markdown]
# #### Checking for Missingness ####

# %%
data.isna().sum()[data.isna().sum() > 0]/len(data)
# Out:
# IntakeSubtype            0.003979
# PrimaryColor             0.000046
# SecondaryBreed           0.725257
# SecondaryColor           0.465401
# DOB                      0.416726
# IntakeReason             0.765838
# OutcomeDate              0.000018
# OutcomeSubtype           0.049604
# OutcomeReason            1.000000
# OutcomeInternalStatus    0.704525
# dtype: float64

# %% [markdown]
# #### Dropping columns with a very high percentage of missing values ####

# %%
data = data.drop(
    ['SecondaryBreed', 'SecondaryColor', 'IntakeReason', 'OutcomeReason', 'OutcomeInternalStatus'], 
    axis = 1)

# %% [markdown]
# Note: Despite having a high percentage of missing values, DOB was not dropped because of its high relevance.

# %% [markdown]
# ### Dealing with Duplicate Entries ####

# %% [markdown]
# #### Checking for duplicate AnimalIDs ####

# %%
dupl_IDs = pd.concat(i for _, i in data.groupby("AnimalID") if len(i) > 1)
dupl_IDs = dupl_IDs.sort_values(by = ['AnimalID', 'IntakeDate'])
print("Number of duplicate AnimalIDs: ", int(len(dupl_IDs)/2))
# Out:
# Number of duplicate AnimalIDs:  7011

# %%
dupl_IDs.head(10)
# Out:
#       AnimalID AnimalType           IntakeDate IntakeType IntakeSubtype  \
# 21436  A000000        CAT  2005-06-02 20:03:00      STRAY         FIELD
# 3740   A000000        CAT  2006-02-02 12:27:00      STRAY         FIELD
# 37717  A000000        CAT  2006-02-14 16:20:00  OWNER SUR           OTC
# 25824  A000049        DOG  2008-11-03 19:33:00  OWNER SUR           OTC
# 41577  A000049        DOG  2009-05-07 12:40:00     RETURN           OTC
# 65131  A000049        DOG  2012-08-04 12:22:00  OWNER SUR           OTC
# 9197   A000220        DOG  2005-02-11 10:07:00      STRAY           OTC
# 6878   A000220        DOG  2005-03-29 11:42:00     RETURN           OTC
# 15447  A000225        DOG  2005-03-02 10:18:00      STRAY           OTC
# 47206  A000225        DOG  2005-03-26 10:56:00     RETURN           OTC
#
#       PrimaryColor                   PrimaryBreed         Gender  \
# 21436        BLACK             DOMESTIC SHORTHAIR  SPAYED FEMALE
# 3740         BLACK             DOMESTIC SHORTHAIR  SPAYED FEMALE
# 37717        BLACK             DOMESTIC SHORTHAIR  SPAYED FEMALE
# 25824          TAN                 COLLIE - ROUGH  SPAYED FEMALE
# 41577          TAN                 COLLIE - ROUGH  SPAYED FEMALE
# 65131          TAN                 COLLIE - ROUGH  SPAYED FEMALE
# 9197         BROWN                         BEAGLE  SPAYED FEMALE
# 6878         BROWN                         BEAGLE  SPAYED FEMALE
# 15447        BLACK  PARSON (JACK) RUSSELL TERRIER           MALE
# 47206        BLACK  PARSON (JACK) RUSSELL TERRIER           MALE
#
#                        DOB IntakeInternalStatus ReproductiveStatusAtIntake  \
# 21436                  NaN               NORMAL                    ALTERED
# 3740                   NaN               NORMAL                    ALTERED
# 37717                  NaN               NORMAL                    ALTERED
# 25824  2002-03-15 00:00:00               NORMAL                    ALTERED
# 41577  2002-03-15 00:00:00               NORMAL                    ALTERED
# 65131  2002-03-15 00:00:00               NORMAL                    ALTERED
# 9197   2002-10-17 00:00:00               NORMAL                    ALTERED
# 6878   2002-10-17 00:00:00               NORMAL                    ALTERED
# 15447  2003-02-17 00:00:00               NORMAL                    FERTILE
# 47206  2003-02-17 00:00:00               NORMAL                    FERTILE
#
#                OutcomeDate OutcomeType OutcomeSubtype
# 21436  2005-06-07 08:00:00        EUTH          FERAL
# 3740   2006-02-03 23:59:00        DIED            NaN
# 37717  2006-04-20 12:00:00        EUTH          FERAL
# 25824  2008-11-06 13:32:00    ADOPTION      WEB METRO
# 41577  2009-05-23 13:04:00    ADOPTION        WALK IN
# 65131  2012-08-17 18:24:00    TRANSFER            NaN
# 9197   2005-03-28 11:09:00    ADOPTION            NaN
# 6878   2005-03-29 15:40:00    ADOPTION            NaN
# 15447  2005-03-19 23:59:00    ADOPTION            NEW
# 47206  2005-04-04 09:00:00        EUTH     BEHAV HIST

# %% [markdown]
# #### Dropping all but the first observation when observations are an EXACT match and reseting index ####

# %%
data = data.drop_duplicates()

# %% [markdown]
# #### Dropping latter of two observations when the same AnimalID results in 2 'EUTH'/'DIED' outcomes

# %%
died_IDs = dupl_IDs[(dupl_IDs['OutcomeType'] == 'EUTH') | (dupl_IDs['OutcomeType'] == 'DIED') | (dupl_IDs['OutcomeType'] == 
                                                                                                'ET PROCESS')]
dupl_died_IDs = pd.concat(i for _, i in died_IDs.groupby("AnimalID") if len(i) > 1)
dupl_TBR = dupl_died_IDs.iloc[range(1, len(dupl_died_IDs), 2)]

data = data.drop(dupl_TBR.index)
data = data.reset_index(drop = True)

# %% [markdown]
# #### Rechecking number of duplicate AnimalIDs ####

# %%
dupl_IDs = pd.concat(i for _, i in data.groupby("AnimalID") if len(i) > 1)
dupl_IDs = dupl_IDs.sort_values(by = ['AnimalID', 'IntakeDate'])
print("Number of remaining duplicate AnimalIDs: ", int(len(dupl_IDs)/2))
# Out:
# Number of remaining duplicate AnimalIDs:  6865

# %% [markdown]
# #### Removing returned animals from duplicate subset ####
# Returned animals count as two observations since being returned often gave a different outcome than the initial outcome. Because of this, they should not be included in the dupl_IDs subset. Removal from this set does not have any affect on the main dataset.

# %%
RETURN_IDs = dupl_IDs[(dupl_IDs['IntakeType'] == 'RETURN') | (dupl_IDs['IntakeSubtype'] == 'RETURN')]['AnimalID'].values
dupl_IDs = dupl_IDs.drop(dupl_IDs[dupl_IDs['AnimalID'].isin(RETURN_IDs)].index)

print("Number of actual remaining duplicate AnimalIDs: ", int(len(dupl_IDs)/2))
# Out:
# Number of actual remaining duplicate AnimalIDs:  1049

# %% [markdown]
# #### Examining remaining duplicate AnimalIDs ####

# %%
dupl_IDs.head(50)
# Out:
#       AnimalID AnimalType           IntakeDate  IntakeType IntakeSubtype  \
# 21420  A000000        CAT  2005-06-02 20:03:00       STRAY         FIELD
# 37687  A000000        CAT  2006-02-14 16:20:00   OWNER SUR           OTC
# 2285   A000849        DOG  2005-03-23 14:43:00   OWNER SUR         FIELD
# 21836  A000849        DOG  2005-07-22 13:05:00   OWNER SUR           OTC
# 68782  A199523        DOG  2014-07-09 16:52:00   OWNER SUR           OTC
# 85029  A199523        DOG  2016-05-17 14:11:00       STRAY         FIELD
# 7736   A238029        DOG  2005-05-09 10:53:00       STRAY         FIELD
# 51714  A238029        DOG  2010-12-31 14:29:00   OWNER SUR         FIELD
# 40655  A239160        CAT  2005-05-18 17:32:00       STRAY           OTC
# 31464  A239160        CAT  2005-05-21 09:13:00       STRAY           OTC
# 38316  A239960        DOG  2005-05-26 12:57:00   OWNER SUR           OTC
# 30570  A239960        DOG  2005-06-23 12:54:00   OWNER SUR           OTC
# 4305   A241497        DOG  2005-06-13 17:56:00  CONFISCATE           NaN
# 19608  A241497        DOG  2005-07-17 09:44:00   OWNER SUR           OTC
# 13728  A246975        DOG  2005-08-14 10:34:00       STRAY         FIELD
# 15759  A246975        DOG  2005-10-03 16:15:00   OWNER SUR           OTC
# 21095  A249321        DOG  2005-09-08 16:51:00   OWNER SUR           OTC
# 51739  A249321        DOG  2005-12-16 17:34:00   OWNER SUR           OTC
# 29144  A251282        DOG  2005-09-30 11:04:00   OWNER SUR           OTC
# 37191  A251282        DOG  2005-10-09 14:59:00   OWNER SUR           OTC
# 13930  A254173        DOG  2005-10-31 16:28:00       STRAY           OTC
# 37673  A254173        DOG  2005-11-15 14:58:00       STRAY           OTC
# 38742  A255764        DOG  2005-11-19 23:13:00   OWNER SUR           OTC
# 51820  A255764        DOG  2006-02-25 14:54:00       STRAY           OTC
# 77333  A258330        DOG  2005-12-15 14:57:00   OWNER SUR           OTC
# 13977  A258330        DOG  2006-04-25 16:25:00       STRAY         FIELD
# 40868  A259489        DOG  2005-12-30 21:47:00   OWNER SUR           OTC
# 5028   A259489        DOG  2006-01-10 11:41:00       STRAY           OTC
# 4170   A260617        DOG  2005-08-28 14:13:00       STRAY           OTC
# 42791  A260617        DOG  2006-01-13 12:17:00   OWNER SUR           OTC
# 26814  A264731        DOG  2006-03-03 11:00:00       STRAY           OTC
# 26212  A264731        DOG  2006-03-15 17:32:00   OWNER SUR           OTC
# 38738  A265491        DOG  2006-03-10 23:28:00   OWNER SUR           OTC
# 25472  A265491        DOG  2006-05-01 11:26:00   OWNER SUR           OTC
# 20650  A266075        DOG  2006-03-16 22:22:00       STRAY         FIELD
# 20054  A266075        DOG  2006-06-19 11:23:00       STRAY         FIELD
# 10327  A269091        CAT  2006-04-21 17:21:00       STRAY           OTC
# 79449  A269091        CAT  2012-12-28 12:27:00       STRAY           OTC
# 34941  A271461        DOG  2006-05-20 13:15:00   OWNER SUR           OTC
# 35798  A271461        DOG  2006-05-26 10:15:00   OWNER SUR           OTC
# 53789  A274330        DOG  2008-05-06 15:15:00       STRAY         FIELD
# 41709  A274330        DOG  2009-06-06 19:10:00       STRAY         FIELD
# 17321  A275539        CAT  2006-07-06 08:49:00   OWNER SUR           OTC
# 28453  A275539        CAT  2008-01-03 12:17:00   OWNER SUR           OTC
# 10668  A276060        DOG  2006-07-17 18:40:00       STRAY         FIELD
# 66252  A276060        DOG  2012-10-27 12:12:00       STRAY           OTC
# 7321   A276903        DOG  2006-07-27 10:13:00       STRAY         FIELD
# 29485  A276903        DOG  2006-08-26 11:22:00   OWNER SUR           OTC
# 14675  A278824        DOG  2006-08-17 11:53:00       STRAY           OTC
# 47438  A278824        DOG  2010-03-03 12:20:00   OWNER SUR           OTC
#
#       PrimaryColor                   PrimaryBreed         Gender  \
# 21420        BLACK             DOMESTIC SHORTHAIR  SPAYED FEMALE
# 37687        BLACK             DOMESTIC SHORTHAIR  SPAYED FEMALE
# 2285         BROWN                         BEAGLE  NEUTERED MALE
# 21836        BROWN                         BEAGLE  NEUTERED MALE
# 68782        BLACK                         BEAGLE  SPAYED FEMALE
# 85029        BLACK                         BEAGLE  SPAYED FEMALE
# 7736         WHITE                   BASSET HOUND  SPAYED FEMALE
# 51714        WHITE                   BASSET HOUND  SPAYED FEMALE
# 40655        WHITE             DOMESTIC SHORTHAIR           MALE
# 31464        WHITE             DOMESTIC SHORTHAIR           MALE
# 38316        BLACK                 COCKER SPANIEL  SPAYED FEMALE
# 30570        BLACK                 COCKER SPANIEL  SPAYED FEMALE
# 4305         BLACK                    RAT TERRIER  SPAYED FEMALE
# 19608        BLACK                    RAT TERRIER  SPAYED FEMALE
# 13728        BROWN                         BEAGLE  SPAYED FEMALE
# 15759        BROWN                         BEAGLE  SPAYED FEMALE
# 21095        CREAM             LABRADOR RETRIEVER  SPAYED FEMALE
# 51739        CREAM             LABRADOR RETRIEVER  SPAYED FEMALE
# 29144        BLACK                     POMERANIAN  SPAYED FEMALE
# 37191        BLACK                     POMERANIAN  SPAYED FEMALE
# 13930        BLACK                     ROTTWEILER         FEMALE
# 37673        BLACK                     ROTTWEILER         FEMALE
# 38742          TAN              DOBERMAN PINSCHER  NEUTERED MALE
# 51820          TAN              DOBERMAN PINSCHER  NEUTERED MALE
# 77333        WHITE            GERMAN SHEPHERD DOG  NEUTERED MALE
# 13977        WHITE            GERMAN SHEPHERD DOG  NEUTERED MALE
# 40868        BLACK                      DALMATIAN           MALE
# 5028         BLACK                      DALMATIAN           MALE
# 4170         WHITE                       BRITTANY           MALE
# 42791        WHITE                       BRITTANY           MALE
# 26814        CREAM      CHIHUAHUA - SMOOTH COATED  NEUTERED MALE
# 26212        CREAM      CHIHUAHUA - SMOOTH COATED  NEUTERED MALE
# 38738        WHITE             LABRADOR RETRIEVER  SPAYED FEMALE
# 25472        WHITE             LABRADOR RETRIEVER  SPAYED FEMALE
# 20650        WHITE                      DALMATIAN           MALE
# 20054        WHITE                      DALMATIAN           MALE
# 10327   GRAY TABBY             DOMESTIC SHORTHAIR  SPAYED FEMALE
# 79449   GRAY TABBY             DOMESTIC SHORTHAIR  SPAYED FEMALE
# 34941        WHITE  PARSON (JACK) RUSSELL TERRIER  SPAYED FEMALE
# 35798        WHITE  PARSON (JACK) RUSSELL TERRIER  SPAYED FEMALE
# 53789        WHITE                 SIBERIAN HUSKY  SPAYED FEMALE
# 41709        WHITE                 SIBERIAN HUSKY  SPAYED FEMALE
# 17321  BROWN TABBY                     MAINE COON  SPAYED FEMALE
# 28453  BROWN TABBY                     MAINE COON  SPAYED FEMALE
# 10668        WHITE                         BEAGLE  NEUTERED MALE
# 66252        WHITE                         BEAGLE  NEUTERED MALE
# 7321          BUFF                       SHIH TZU  NEUTERED MALE
# 29485         BUFF                       SHIH TZU  NEUTERED MALE
# 14675       YELLOW             LABRADOR RETRIEVER  SPAYED FEMALE
# 47438       YELLOW             LABRADOR RETRIEVER  SPAYED FEMALE
#
#                        DOB IntakeInternalStatus ReproductiveStatusAtIntake  \
# 21420                  NaN               NORMAL                    ALTERED
# 37687                  NaN               NORMAL                    ALTERED
# 2285   2002-12-18 00:00:00               NORMAL                    ALTERED
# 21836  2002-12-18 00:00:00               NORMAL                    ALTERED
# 68782  2002-10-18 00:00:00               NORMAL                    ALTERED
# 85029  2002-10-18 00:00:00              INJURED                    ALTERED
# 7736   2003-06-03 00:00:00               NORMAL                    ALTERED
# 51714  2003-06-03 00:00:00               NORMAL                    ALTERED
# 40655                  NaN               NORMAL                    FERTILE
# 31464                  NaN               NORMAL                    FERTILE
# 38316  2004-11-26 00:00:00               NORMAL                    ALTERED
# 30570  2004-11-26 00:00:00               NORMAL                    ALTERED
# 4305   2001-06-21 00:00:00               NORMAL                    ALTERED
# 19608  2001-06-21 00:00:00               NORMAL                    ALTERED
# 13728  2004-08-19 00:00:00               NORMAL                    ALTERED
# 15759  2004-08-19 00:00:00               NORMAL                    ALTERED
# 21095                  NaN               NORMAL                    ALTERED
# 51739                  NaN               NORMAL                    ALTERED
# 29144  2005-02-27 00:00:00               NORMAL                    ALTERED
# 37191  2005-02-27 00:00:00               NORMAL                    ALTERED
# 13930  2004-05-14 00:00:00               NORMAL                    FERTILE
# 37673  2004-05-14 00:00:00               NORMAL                    FERTILE
# 38742  2005-01-07 00:00:00               NORMAL                    ALTERED
# 51820  2005-01-07 00:00:00               NORMAL                    ALTERED
# 77333  1997-12-15 00:00:00               NORMAL                    ALTERED
# 13977  1997-12-15 00:00:00               NORMAL                    ALTERED
# 40868  2005-03-02 00:00:00               NORMAL                    FERTILE
# 5028   2005-03-02 00:00:00               NORMAL                    FERTILE
# 4170                   NaN               NORMAL                    FERTILE
# 42791                  NaN               NORMAL                    FERTILE
# 26814  2002-03-15 00:00:00               NORMAL                    ALTERED
# 26212  2002-03-15 00:00:00               NORMAL                    ALTERED
# 38738  2006-01-10 00:00:00               NORMAL                    ALTERED
# 25472  2006-01-10 00:00:00               NORMAL                    ALTERED
# 20650  2005-10-23 00:00:00               NORMAL                    FERTILE
# 20054  2005-10-23 00:00:00               NORMAL                    FERTILE
# 10327  2004-10-21 00:00:00               NORMAL                    ALTERED
# 79449  2004-10-21 00:00:00               NORMAL                    ALTERED
# 34941  2005-08-20 00:00:00               NORMAL                    ALTERED
# 35798  2005-08-20 00:00:00               NORMAL                    ALTERED
# 53789  2007-06-02 00:00:00               NORMAL                    ALTERED
# 41709  2007-06-02 00:00:00               NORMAL                    ALTERED
# 17321  2003-07-11 00:00:00               NORMAL                    ALTERED
# 28453  2003-07-11 00:00:00               NORMAL                    ALTERED
# 10668  2006-05-02 00:00:00               NORMAL                    ALTERED
# 66252  2006-05-02 00:00:00               NORMAL                    ALTERED
# 7321   2001-08-22 00:00:00               NORMAL                    ALTERED
# 29485  2001-08-22 00:00:00               NORMAL                    ALTERED
# 14675  2002-03-01 00:00:00               NORMAL                    ALTERED
# 47438  2002-03-01 00:00:00               NORMAL                    ALTERED
#
#                OutcomeDate OutcomeType OutcomeSubtype
# 21420  2005-06-07 08:00:00        EUTH          FERAL
# 37687  2006-04-20 12:00:00        EUTH          FERAL
# 2285   2005-07-13 16:23:00    ADOPTION            NaN
# 21836  2005-07-26 23:59:00    ADOPTION            NaN
# 68782  2014-08-21 17:45:00    ADOPTION        WALK IN
# 85029  2016-05-28 08:20:00   TRANSPORT     RESCUE GRP
# 7736   2005-06-03 15:26:00    ADOPTION            NaN
# 51714  2011-01-16 20:28:00    TRANSFER     RESCUE GRP
# 40655  2005-05-21 12:01:00    ADOPTION     RESCUE GRP
# 31464  2005-05-23 10:00:00    ADOPTION     RESCUE GRP
# 38316  2005-06-03 11:52:00    ADOPTION            NaN
# 30570  2005-07-02 11:50:00    ADOPTION            NaN
# 4305   2005-07-15 10:41:00    ADOPTION            NaN
# 19608  2005-07-23 10:04:00    TRANSFER     RESCUE GRP
# 13728  2005-09-20 12:32:00    ADOPTION            NaN
# 15759  2005-10-14 14:52:00    ADOPTION            NaN
# 21095  2005-11-05 12:54:00    ADOPTION            NaN
# 51739  2006-02-03 11:23:00    TRANSFER     RESCUE GRP
# 29144  2005-10-05 13:05:00    ADOPTION            NaN
# 37191  2005-10-11 12:13:00    ADOPTION            NaN
# 13930  2005-11-11 23:59:00    TRANSFER     AN CONTROL
# 37673  2005-11-23 15:02:00    TRANSFER     RESCUE GRP
# 38742  2006-01-28 16:48:00    ADOPTION            NaN
# 51820  2006-04-25 13:44:00        EUTH     TIME/SPACE
# 77333  2006-01-21 16:50:00    ADOPTION            NaN
# 13977  2006-09-11 17:12:00    ADOPTION            NaN
# 40868  2005-12-31 23:59:00    TRANSFER            KHS
# 5028   2006-01-10 23:59:00        EUTH     BEHAV OBSV
# 4170   2005-12-03 11:24:00    ADOPTION            NaN
# 42791  2006-01-25 23:59:00        EUTH          BREED
# 26814  2006-03-15 12:09:00    ADOPTION        WALK IN
# 26212  2006-03-17 15:07:00    TRANSFER     RESCUE GRP
# 38738  2006-04-20 13:19:00    ADOPTION            NaN
# 25472  2006-06-03 10:57:00    ADOPTION            NaN
# 20650  2006-03-23 13:57:00    ADOPTION            NaN
# 20054  2006-08-08 10:33:00        EUTH     BEHAV OBSV
# 10327  2007-06-06 10:43:00    ADOPTION            NaN
# 79449  2013-01-15 19:37:00        EUTH     BEHAV OBSV
# 34941  2006-05-23 16:30:00    ADOPTION            NaN
# 35798  2006-05-26 14:06:00    TRANSFER     RESCUE GRP
# 53789  2008-06-02 16:35:00    ADOPTION         FRIEND
# 41709  2009-07-06 13:50:00    ADOPTION         FRIEND
# 17321  2006-08-29 12:33:00    ADOPTION        WALK IN
# 28453  2008-01-17 12:14:00    ADOPTION        WALK IN
# 10668  2006-07-24 16:39:00    ADOPTION            NaN
# 66252  2012-11-30 14:29:00        EUTH     BEHAV HIST
# 7321   2006-08-22 16:09:00    ADOPTION            NaN
# 29485  2006-09-15 11:00:00    TRANSFER     RESCUE GRP
# 14675  2006-08-29 12:23:00    ADOPTION            NaN
# 47438  2010-04-06 15:55:00    ADOPTION         FRIEND

# %% [markdown]
# It appears that the remaining duplicate AnimalIDs do belong do the same animals. However, these observations should still be useful because they take place under different circumstances and often have different outcomes.

# %% [markdown]
# ### Basic Feature Modifications ###
#
# A few feature modifications were done that will apply to both the dog and cat models.

# %% [markdown]
# #### Changing Genders 'NEUTERED MALE' and 'SPAYED FEMALE' to simply 'MALE' and 'FEMALE' ####
# The labels 'neutered' and 'spayed' should correspond to 'fertile' and 'altered' for ReproductiveStatusAtIntake, but they do not. It was determined that due to the frequency of each value, the 'fertile' and 'altered' labels were true, whereas the 'neutered' and 'spayed' labels were incorrectly done.

# %%
def gender_transform(gender):

    if gender == 'NEUTERED MALE':
        return 'MALE'
    elif gender == 'SPAYED FEMALE':
        return 'FEMALE'
    else:
        return gender
    
data['Gender'] = data['Gender'].apply(gender_transform)

# %% [markdown]
# #### Changing OutcomeType 'ET PROCESS' to 'EUTH' ####
# 'ET PROCESS' is used to denote an animal that is going to be euthanized. However, this outcome type was never changed when they were euthanized.

# %%
def ETtoEUTH(OutcomeType):
    if OutcomeType == 'ET PROCESS':
        return 'EUTH'
    else:
        return OutcomeType
    
data['OutcomeType'] = data['OutcomeType'].apply(ETtoEUTH)

# %% [markdown]
# #### Changing OutcomeSubtypes 'TIME' and 'SPACE' to 'TIME/SPACE' ####
# 'TIME/SPACE' should cover 'TIME' and 'SPACE' and the differentiation is likely arbitrary.

# %%
def TStoTS(OutcomeSubtype):
    if ((OutcomeSubtype == 'TIME') | (OutcomeSubtype == 'SPACE')):
        return 'TIME/SPACE'
    else:
        return OutcomeSubtype
    
data['OutcomeSubtype'] = data['OutcomeSubtype'].apply(TStoTS)

# %% [markdown]
# #### Getting value from dates ####
# Date columns were changed to a datetime type and were then subsequently used to creature other features, such as Intake/Outcome Month, Intake/Outcome Year, Intake/Outcome DotW (day of the week), IntakeAge, and TimeUntilOutcome.

# %%
IntakeDate = pd.to_datetime(data['IntakeDate'], infer_datetime_format = True).dt.strftime('%m-%d-%Y')
OutcomeDate = pd.to_datetime(data['OutcomeDate'], infer_datetime_format = True).dt.strftime('%m-%d-%Y')
DOB = pd.to_datetime(data['DOB'], infer_datetime_format = True).dt.strftime('%m-%d-%Y')

data['IntakeDate'] = pd.to_datetime(IntakeDate)
data['OutcomeDate'] = pd.to_datetime(OutcomeDate)
data['DOB'] = pd.to_datetime(DOB)

# %%
def get_month(date):
    return date.month

def get_year(date):
    return date.year

def get_dotw(date):
    return date.dayofweek


data['IntakeMonth'] = data['IntakeDate'].apply(get_month)
data['IntakeYear'] = data['IntakeDate'].apply(get_year)
data['IntakeDotW'] = data['IntakeDate'].apply(get_dotw)

data = data[-data['OutcomeDate'].isna()]
data['OutcomeMonth'] = data['OutcomeDate'].apply(get_month)
data['OutcomeYear'] = data['OutcomeDate'].apply(get_year)
data['OutcomeDotW'] = data['OutcomeDate'].apply(get_dotw)

# %%
IntakeAge = data['IntakeDate'] - data['DOB']
TimeUntilOutcome = data['OutcomeDate'] - data['IntakeDate']

# %%
data['IntakeAge'] = pd.to_numeric(IntakeAge.dt.days, downcast='integer')

def invalid_age(IntakeAge):
    if IntakeAge < 0:
        return np.nan
    else:
        return IntakeAge

data['IntakeAge'] = data['IntakeAge'].apply(invalid_age) # replacing negative ages with NaN

# %%
data['TimeUntilOutcome'] = pd.to_numeric(TimeUntilOutcome.dt.days, downcast='integer')
data = data[data['TimeUntilOutcome'] >= 0]  # removing data where OutcomeDate was before IntakeDate

# %% [markdown]
# #### Adding 'LiveOutcome' column ####
# The model seeks to classify whether an animal is euthanized or not, so the binary 'LiveOutcome' feature is created.

# %%
def live_outcome(OutcomeType):
    if ((OutcomeType == 'EUTH') | (OutcomeType == 'DIED')):
        return 0
    else:
        return 1
    
data['LiveOutcome'] = data['OutcomeType'].apply(live_outcome)

# %% [markdown]
# #### Removing newly redundant columns ####

# %%
data = data.drop(['IntakeDate', 'OutcomeDate', 'DOB'], axis=1)

# %% [markdown]
# ### Preprocessed Data Preview ###

# %%
print("Total Observations: ", len(data))
data.head(20)
# Out:
# Total Observations:  109610
#    AnimalID AnimalType  IntakeType IntakeSubtype   PrimaryColor  \
# 0   A366370        CAT       STRAY           OTC          WHITE
# 1   A366531        CAT       STRAY           OTC          BLACK
# 2   A281756        DOG   OWNER SUR           OTC          WHITE
# 3   A256128        DOG       STRAY         FIELD          BROWN
# 4   A314432        CAT   OWNER SUR           OTC    BROWN TABBY
# 5   A316619        DOG       STRAY         FIELD          WHITE
# 6   A317335        CAT       STRAY           OTC           GRAY
# 7   A317486        CAT       STRAY           OTC           GRAY
# 8   A318485        CAT   OWNER SUR           OTC          BLACK
# 9   A318496        CAT       STRAY         FIELD    BLACK TIGER
# 10  A318533        CAT       STRAY         FIELD          BLACK
# 11  A319056        DOG       STRAY           OTC       TRICOLOR
# 12  A325393        CAT       STRAY           OTC           GRAY
# 13  A258842        DOG  CONFISCATE       NEGLECT          WHITE
# 14  A258896        DOG       STRAY           OTC  BROWN BRINDLE
# 15  A252704        DOG       STRAY           OTC            TAN
# 16  A252809        CAT         KHS         STRAY    BLACK TIGER
# 17  A253104        DOG       STRAY         FIELD          BLACK
# 18  A254123        CAT       STRAY         FIELD          BLACK
# 19  A000120        DOG       STRAY           OTC          BLACK
#
#                  PrimaryBreed   Gender IntakeInternalStatus  \
# 0          DOMESTIC SHORTHAIR     MALE              FEARFUL
# 1          DOMESTIC SHORTHAIR  UNKNOWN               NORMAL
# 2            PIT BULL TERRIER     MALE               NORMAL
# 3   AMERICAN PIT BULL TERRIER     MALE               NORMAL
# 4          DOMESTIC SHORTHAIR  UNKNOWN               NORMAL
# 5          LABRADOR RETRIEVER     MALE              FEARFUL
# 6          DOMESTIC SHORTHAIR  UNKNOWN               NORMAL
# 7          DOMESTIC SHORTHAIR   FEMALE              NURSING
# 8           DOMESTIC LONGHAIR   FEMALE               NORMAL
# 9          DOMESTIC SHORTHAIR  UNKNOWN               NORMAL
# 10        DOMESTIC MEDIUMHAIR     MALE                 SICK
# 11                     BEAGLE     MALE               NORMAL
# 12         DOMESTIC SHORTHAIR   FEMALE              NURSING
# 13           PIT BULL TERRIER     MALE               NORMAL
# 14  AMERICAN PIT BULL TERRIER     MALE               NORMAL
# 15           AIREDALE TERRIER   FEMALE               NORMAL
# 16         DOMESTIC SHORTHAIR     MALE               NORMAL
# 17           PIT BULL TERRIER     MALE              INJURED
# 18         DOMESTIC SHORTHAIR     MALE               NORMAL
# 19                     BEAGLE   FEMALE               NORMAL
#
#    ReproductiveStatusAtIntake OutcomeType OutcomeSubtype  IntakeMonth  \
# 0                     ALTERED        EUTH          FERAL           11
# 1                     UNKNOWN        EUTH     CONTAG DIS           11
# 2                     FERTILE        EUTH     TIME/SPACE            9
# 3                     FERTILE        EUTH        MEDICAL           11
# 4                     UNKNOWN        EUTH     TIME/SPACE            6
# 5                     FERTILE        EUTH     TIME/SPACE            6
# 6                     UNKNOWN        EUTH     TIME/SPACE            7
# 7                     FERTILE        EUTH     TIME/SPACE            7
# 8                     ALTERED        EUTH     TIME/SPACE            7
# 9                     UNKNOWN        EUTH     TIME/SPACE            7
# 10                    ALTERED        EUTH        MEDICAL            7
# 11                    ALTERED        EUTH     TIME/SPACE            7
# 12                    FERTILE        EUTH     CONTAG DIS            9
# 13                    FERTILE        EUTH          BREED           12
# 14                    FERTILE        EUTH          BREED           12
# 15                    FERTILE        EUTH     TIME/SPACE           10
# 16                    FERTILE        EUTH     TIME/SPACE           10
# 17                    FERTILE        EUTH     TIME/SPACE           10
# 18                    FERTILE        EUTH     TIME/SPACE           10
# 19                    FERTILE        EUTH          BREED            3
#
#     IntakeYear  IntakeDotW  OutcomeMonth  OutcomeYear  OutcomeDotW  IntakeAge  \
# 0         2008           4            11         2008            2        NaN
# 1         2008           0            11         2008            2        NaN
# 2         2006           0             9         2006            1      365.0
# 3         2005           5            12         2005            3        NaN
# 4         2007           4             6         2007            4        NaN
# 5         2007           4             7         2007            2        NaN
# 6         2007           3             7         2007            2        NaN
# 7         2007           4             7         2007            3        NaN
# 8         2007           5             7         2007            5        NaN
# 9         2007           5             7         2007            3        NaN
# 10        2007           5             7         2007            6        NaN
# 11        2007           3             8         2007            1        NaN
# 12        2007           5             9         2007            3        NaN
# 13        2005           2            12         2005            3        NaN
# 14        2005           3            12         2005            2        NaN
# 15        2005           5            10         2005            3        NaN
# 16        2005           0            10         2005            5        NaN
# 17        2005           2            10         2005            1        NaN
# 18        2005           0            11         2005            1        NaN
# 19        2005           1             3         2005            5        NaN
#
#     TimeUntilOutcome  LiveOutcome
# 0                  5            0
# 1                  9            0
# 2                  1            0
# 3                 12            0
# 4                  0            0
# 5                  5            0
# 6                  6            0
# 7                  6            0
# 8                  0            0
# 9                  5            0
# 10                 1            0
# 11                19            0
# 12                 5            0
# 13                 8            0
# 14                 6            0
# 15                 5            0
# 16                 5            0
# 17                 6            0
# 18                 8            0
# 19                 4            0

# %% [markdown]
# ### Saving Preprocessed Data ###

# %%
data.to_csv('preprocessed_data.csv')
