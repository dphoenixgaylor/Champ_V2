# %% [markdown]
# # CATS: Further Data Preprocessing #

# %% [markdown]
# ### Imports ###

# %%
import pandas as pd
import numpy as np
import datetime
import re

# %% [markdown]
# ### Data Preview ###
# Cat data was extracted from the data exported from the Champ_Preprocessing notebook.

# %%
data = pd.read_csv('preprocessed_data.csv', index_col=0)

# %%
cat_data = data[data['AnimalType'] == 'CAT'].reset_index(drop=True)
cat_data = cat_data.drop('AnimalType', axis=1)
print("Total Observations: ", len(cat_data))
cat_data.head()
# Out:
# Total Observations:  57350
#   AnimalID IntakeType IntakeSubtype PrimaryColor        PrimaryBreed   Gender  \
# 0  A366370      STRAY           OTC        WHITE  DOMESTIC SHORTHAIR     MALE
# 1  A366531      STRAY           OTC        BLACK  DOMESTIC SHORTHAIR  UNKNOWN
# 2  A314432  OWNER SUR           OTC  BROWN TABBY  DOMESTIC SHORTHAIR  UNKNOWN
# 3  A317335      STRAY           OTC         GRAY  DOMESTIC SHORTHAIR  UNKNOWN
# 4  A317486      STRAY           OTC         GRAY  DOMESTIC SHORTHAIR   FEMALE
#
#   IntakeInternalStatus ReproductiveStatusAtIntake OutcomeType OutcomeSubtype  \
# 0              FEARFUL                    ALTERED        EUTH          FERAL
# 1               NORMAL                    UNKNOWN        EUTH     CONTAG DIS
# 2               NORMAL                    UNKNOWN        EUTH     TIME/SPACE
# 3               NORMAL                    UNKNOWN        EUTH     TIME/SPACE
# 4              NURSING                    FERTILE        EUTH     TIME/SPACE
#
#    IntakeMonth  IntakeYear  IntakeDotW  OutcomeMonth  OutcomeYear  \
# 0           11        2008           4            11         2008
# 1           11        2008           0            11         2008
# 2            6        2007           4             6         2007
# 3            7        2007           3             7         2007
# 4            7        2007           4             7         2007
#
#    OutcomeDotW  IntakeAge  TimeUntilOutcome  LiveOutcome
# 0            2        NaN                 5            0
# 1            2        NaN                 9            0
# 2            4        NaN                 0            0
# 3            2        NaN                 6            0
# 4            3        NaN                 6            0

# %% [markdown]
# ### Feature Value Reduction ###
# The number of feature values  were reduced to help with training the model later on and to categorize values that may have been assigned differently arbitrarily.

# %% [markdown]
# #### Combining IntakeType and IntakeSubtype ####

# %%
cat_data['IntakeTypes'] = cat_data['IntakeType'].map(str) + ',' + cat_data['IntakeSubtype']
cat_data = cat_data.drop(['IntakeType', 'IntakeSubtype'], axis=1)

# %% [markdown]
# #### Classifying the IntakeTypes into 10 categories ####
# Many of the combined intake types were very similar and can be grouped together.

# %%
def cat_IntakeType(IntakeTypes):
    IntakeTypes = str(IntakeTypes)
    t1 = re.compile("CONFISCATE,ABANDONED|CONFISCATE,NEGLECT|CONFISCATE,CRUELTY")
    t2 = re.compile(
        "CONFISCATE,EVICTION|CONFISCATE,UNPERMITED|CONFISCATE,POLICE|CONFISCATE,HOSPITAL|CONFISCATE,OWNER DIED|CONFISCATE,RESTRAINT")
    t3 = re.compile("FOSTER,RETURN|RETURN,FOSTER")
    t4 = re.compile("OWNER SUR,FIELD|KHS,OWNER SUR")
    t5 = re.compile("OWNER SUR,OTC")
    t6 = re.compile("OWNER SUR,RETURN 30|RETURN,ADOPTION|RETURN,FIELD|RETURN,K HUMANE S|RETURN,OTC")
    t7 = re.compile("KHS,STRAY")
    t8 = re.compile("STRAY,FIELD|STRAY,STRAY")
    t9 = re.compile("STRAY,OTC|OWNER SUR,STRAY")
    
    if t1.match(IntakeTypes):
        return 'CONFISCATE,CRUELTY'
    elif t2.match(IntakeTypes):
        return 'CONFISCATE,OTHER'
    elif t3.match(IntakeTypes):
        return 'FOSTER'
    elif t4.match(IntakeTypes):
        return 'OWNERSUR,FIELD'
    elif t5.match(IntakeTypes):
        return 'OWNERSUR,OTC'
    elif t6.match(IntakeTypes):
        return 'RETURN'
    elif t7.match(IntakeTypes):
        return 'STRAY,KHS'
    elif t8.match(IntakeTypes):
        return 'STRAY,FIELD'
    elif t9.match(IntakeTypes):
        return 'STRAY,OTC'
    else:
        return 'OTHER'

# %%
cat_data['IntakeTypes'] = cat_data['IntakeTypes'].apply(cat_IntakeType)
cat_data.groupby('IntakeTypes').count()['AnimalID']
# Out:
# IntakeTypes
# CONFISCATE,CRUELTY      309
# CONFISCATE,OTHER         45
# FOSTER                 3301
# OTHER                   208
# OWNERSUR,FIELD         1723
# OWNERSUR,OTC          12070
# RETURN                  583
# STRAY,FIELD           16834
# STRAY,KHS               370
# STRAY,OTC             21907
# Name: AnimalID, dtype: int64

# %% [markdown]
# #### Categorizing cat colors ####

# %%
def cat_color_class(color):
    color = str(color)
    c1 = re.compile("ORANGE|APRICOT|FLAME|RED|TABBY")
    c2 = re.compile("GRAY|BLUE|SEAL|SILVER")
    c3 = re.compile("CREAM|BUFF|GOLD|TAN|YELLOW")
    c4 = re.compile("BROWN|CHOCOLATE|MAHOGANY|SABLE")
    c5 = re.compile("WHITE|LYNX")
    c6 = re.compile("TORTIE|TORTI")
    c7 = re.compile("BLACK")
    c8 = re.compile("CALICO")
   
    if c1.match(color):
        return 'ORANGE'
    elif c2.match(color):
        return 'GRAY'
    elif c3.match(color):
        return 'CREAM'
    elif c4.match(color):
        return 'BROWN'
    elif c5.match(color):
        return 'WHITE'
    elif c6.match(color):
        return 'TORTIE'
    elif c7.match(color):
        return 'BLACK'
    elif c8.match(color):
        return 'CALICO'
    else:
        return 'OTHER'

# %%
cat_data['Color'] = cat_data['PrimaryColor'].str.split().str[0]
cat_data['Color'] = cat_data['Color'].apply(cat_color_class)
cat_data = cat_data.drop('PrimaryColor', axis=1)

# %%
cat_data.groupby('Color').count()['AnimalID']
# Out:
# Color
# BLACK     16915
# BROWN      7192
# CALICO     3285
# CREAM      1921
# GRAY      13341
# ORANGE     6835
# OTHER       166
# TORTIE     2886
# WHITE      4809
# Name: AnimalID, dtype: int64

# %% [markdown]
# #### Categorizing cat breeds ####

# %%
def cat_breed(breed):
    breed = str(breed)
    
    if (breed == 'DOMESTIC LONGHAIR'):
        return 'LONG'
    elif (breed == 'DOMESTIC MEDIUMHAIR'):
        return 'MED'
    elif (breed == 'DOMESTIC SHORTHAIR'):
        return 'SHORT'
    elif (breed == 'AMERICAN SHORTHAIR'):
        return 'AMSHORT'
    elif (breed == 'SIAMESE'):
        return 'SIAMESE'
    elif (breed != 'NaN'):
        return 'OTHER'
    else:
        return 'NONE'

# %%
cat_data['Breed'] = cat_data['PrimaryBreed'].apply(cat_breed)
cat_data = cat_data.drop('PrimaryBreed', axis=1)

# %%
cat_data.groupby('Breed').count()['AnimalID']
# Out:
# Breed
# AMSHORT     1325
# LONG        2646
# MED         5073
# OTHER       1174
# SHORT      46076
# SIAMESE     1056
# Name: AnimalID, dtype: int64

# %% [markdown]
# ### Preprocessed Cat Data Preview ###

# %%
print("Total Observations: ", len(cat_data))
cat_data.head(20)
# Out:
# Total Observations:  57350
#    AnimalID   Gender IntakeInternalStatus ReproductiveStatusAtIntake  \
# 0   A366370     MALE              FEARFUL                    ALTERED
# 1   A366531  UNKNOWN               NORMAL                    UNKNOWN
# 2   A314432  UNKNOWN               NORMAL                    UNKNOWN
# 3   A317335  UNKNOWN               NORMAL                    UNKNOWN
# 4   A317486   FEMALE              NURSING                    FERTILE
# 5   A318485   FEMALE               NORMAL                    ALTERED
# 6   A318496  UNKNOWN               NORMAL                    UNKNOWN
# 7   A318533     MALE                 SICK                    ALTERED
# 8   A325393   FEMALE              NURSING                    FERTILE
# 9   A252809     MALE               NORMAL                    FERTILE
# 10  A254123     MALE               NORMAL                    FERTILE
# 11  A254608     MALE               NORMAL                    FERTILE
# 12  A276679   FEMALE               NORMAL                    FERTILE
# 13  A241284   FEMALE               NORMAL                    FERTILE
# 14  A241576     MALE               NORMAL                    FERTILE
# 15  A256086     MALE               NORMAL                    ALTERED
# 16  A256091   FEMALE               NORMAL                    FERTILE
# 17  A314425  UNKNOWN                FERAL                    UNKNOWN
# 18  A317334  UNKNOWN               NORMAL                    UNKNOWN
# 19  A317457  UNKNOWN               NORMAL                    UNKNOWN
#
#    OutcomeType OutcomeSubtype  IntakeMonth  IntakeYear  IntakeDotW  \
# 0         EUTH          FERAL           11        2008           4
# 1         EUTH     CONTAG DIS           11        2008           0
# 2         EUTH     TIME/SPACE            6        2007           4
# 3         EUTH     TIME/SPACE            7        2007           3
# 4         EUTH     TIME/SPACE            7        2007           4
# 5         EUTH     TIME/SPACE            7        2007           5
# 6         EUTH     TIME/SPACE            7        2007           5
# 7         EUTH        MEDICAL            7        2007           5
# 8         EUTH     CONTAG DIS            9        2007           5
# 9         EUTH     TIME/SPACE           10        2005           0
# 10        EUTH     TIME/SPACE           10        2005           0
# 11        EUTH     TIME/SPACE           11        2005           0
# 12        EUTH     TIME/SPACE            7        2006           0
# 13        EUTH     TIME/SPACE            6        2005           4
# 14        EUTH        MEDICAL            6        2005           1
# 15    TRANSFER     RESCUE GRP           11        2005           4
# 16        EUTH      TOO YOUNG           11        2005           4
# 17        EUTH     BEHAV OBSV            6        2007           4
# 18        EUTH     TIME/SPACE            7        2007           3
# 19        EUTH     TIME/SPACE            7        2007           4
#
#     OutcomeMonth  OutcomeYear  OutcomeDotW  IntakeAge  TimeUntilOutcome  \
# 0             11         2008            2        NaN                 5
# 1             11         2008            2        NaN                 9
# 2              6         2007            4        NaN                 0
# 3              7         2007            2        NaN                 6
# 4              7         2007            3        NaN                 6
# 5              7         2007            5        NaN                 0
# 6              7         2007            3        NaN                 5
# 7              7         2007            6        NaN                 1
# 8              9         2007            3        NaN                 5
# 9             10         2005            5        NaN                 5
# 10            11         2005            1        NaN                 8
# 11            11         2005            5        NaN                 5
# 12             8         2006            2        NaN                 9
# 13             6         2005            2        NaN                 5
# 14             6         2005            0        NaN                 6
# 15            12         2005            5        NaN                22
# 16            12         2005            3        NaN                 6
# 17             6         2007            4        NaN                 0
# 18             7         2007            2        NaN                 6
# 19             7         2007            4       61.0                 0
#
#     LiveOutcome   IntakeTypes   Color    Breed
# 0             0     STRAY,OTC   WHITE    SHORT
# 1             0     STRAY,OTC   BLACK    SHORT
# 2             0  OWNERSUR,OTC   BROWN    SHORT
# 3             0     STRAY,OTC    GRAY    SHORT
# 4             0     STRAY,OTC    GRAY    SHORT
# 5             0  OWNERSUR,OTC   BLACK     LONG
# 6             0   STRAY,FIELD   BLACK    SHORT
# 7             0   STRAY,FIELD   BLACK      MED
# 8             0     STRAY,OTC    GRAY    SHORT
# 9             0     STRAY,KHS   BLACK    SHORT
# 10            0   STRAY,FIELD   BLACK    SHORT
# 11            0     STRAY,KHS    GRAY      MED
# 12            0     STRAY,OTC   WHITE    SHORT
# 13            0     STRAY,OTC  ORANGE      MED
# 14            0     STRAY,OTC    GRAY  AMSHORT
# 15            1     STRAY,OTC  ORANGE    SHORT
# 16            0     STRAY,OTC   BLACK    SHORT
# 17            0  OWNERSUR,OTC  CALICO    SHORT
# 18            0     STRAY,OTC    GRAY    SHORT
# 19            0  OWNERSUR,OTC    GRAY    SHORT

# %% [markdown]
# ### Saving Preprocessed Cat Data ###

# %%
cat_data.to_csv('cat_data.csv')
